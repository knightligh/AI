# %% [markdown]
# <a href="https://colab.research.google.com/github/knightligh/AI/blob/main/Research_paper_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install scikit-fuzzy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 994.0/994.0 KB 13.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for scikit-fuzzy: filename=scikit_fuzzy-0.4.2-py3-none-any.whl size=894088 sha256=cc5b5b54efa9880c0d4f50e247f5ee4117c8fd1ce88c235e2da9ff45d50317e7
#   Stored in directory: /root/.cache/pip/wheels/2c/04/80/7eefb1a2de7d36aefd06432fab2a1486caf0a0596a7067391a
# Successfully built scikit-fuzzy
# ...

# %%
pip install matplotlib
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import numpy as np
import skfuzzy as fuzz
from skfuzzy import control as ctrl 

fever = ctrl.Antecedent(np.arange(1,11,0.5),'fever')
headache= ctrl.Antecedent(np.arange(1,11,0.5),'headache')
nausea = ctrl.Antecedent(np.arange(1,11,0.5),'nausea')
vomiting= ctrl.Antecedent(np.arange(1,11,0.5),'vomiting')
jaundice = ctrl.Antecedent(np.arange(1,11,0.5),'jaundice')
enlarge_liver= ctrl.Antecedent(np.arange(1,11,0.5),'enlarge_liver')
joint_pain = ctrl.Antecedent(np.arange(1,11,0.5),'joint_pain')
body_weakness= ctrl.Antecedent(np.arange(1,11,0.5),'body_weakness')
dizziness = ctrl.Antecedent(np.arange(1,11,0.5),'dizziness')
loss_of_appetie= ctrl.Antecedent(np.arange(1,11,0.5),'loss_of_appetie')
mp= ctrl.Antecedent(np.arange(1,11,0.5),'mp')

conclusion= ctrl.Consequent(np.arange(1,11,0.5),'conclusion')

#------------------1.fever-------------
fever['mild']=fuzz.trimf(fever.universe,[1,2,3])
fever['moderate']=fuzz.trimf(fever.universe,[3,4.5,6])
fever['severe']=fuzz.trimf(fever.universe,[6,7,8])
fever['very severe']=fuzz.trimf(fever.universe,[8,9,10])
fever.view()
#------------------2.headache-------------
headache['mild']=fuzz.trimf(headache.universe,[1,2,3])
headache['moderate']=fuzz.trimf(headache.universe,[3,4.5,6])
headache['severe']=fuzz.trimf(headache.universe,[6,7,8])
headache['very severe']=fuzz.trimf(headache.universe,[8,9,10])
#------------------3.nausea-------------
nausea['mild']=fuzz.trimf(nausea.universe,[1,2,3])
nausea['moderate']=fuzz.trimf(nausea.universe,[3,4.5,6])
nausea['severe']=fuzz.trimf(nausea.universe,[6,7,8])
nausea['very severe']=fuzz.trimf(nausea.universe,[8,9,10])
#------------------4.vomiting-------------
vomiting['mild']=fuzz.trimf(vomiting.universe,[1,2,3])
vomiting['moderate']=fuzz.trimf(vomiting.universe,[3,4.5,6])
vomiting['severe']=fuzz.trimf(vomiting.universe,[6,7,8])
vomiting['very severe']=fuzz.trimf(vomiting.universe,[8,9,10])
#------------------5.jaundice-------------
jaundice['mild']=fuzz.trimf(jaundice.universe,[1,2,3])
jaundice['moderate']=fuzz.trimf(jaundice.universe,[3,4.5,6])
jaundice['severe']=fuzz.trimf(jaundice.universe,[6,7,8])
jaundice['very severe']=fuzz.trimf(jaundice.universe,[8,9,10])
#------------------6.enlarge_liver-------------
enlarge_liver['mild']=fuzz.trimf(enlarge_liver.universe,[1,2,3])
enlarge_liver['moderate']=fuzz.trimf(enlarge_liver.universe,[3,4.5,6])
enlarge_liver['severe']=fuzz.trimf(enlarge_liver.universe,[6,7,8])
enlarge_liver['very severe']=fuzz.trimf(enlarge_liver.universe,[8,9,10])
#------------------7.joint_pain-------------
joint_pain['mild']=fuzz.trimf(joint_pain.universe,[1,2,3])
joint_pain['moderate']=fuzz.trimf(joint_pain.universe,[3,4.5,6])
joint_pain['severe']=fuzz.trimf(joint_pain.universe,[6,7,8])
joint_pain['very severe']=fuzz.trimf(joint_pain.universe,[8,9,10])
#------------------8.body_weakness-------------
body_weakness['mild']=fuzz.trimf(body_weakness.universe,[1,2,3])
body_weakness['moderate']=fuzz.trimf(body_weakness.universe,[3,4.5,6])
body_weakness['severe']=fuzz.trimf(body_weakness.universe,[6,7,8])
body_weakness['very severe']=fuzz.trimf(body_weakness.universe,[8,9,10])
#------------------9.dizziness-------------
dizziness['mild']=fuzz.trimf(dizziness.universe,[1,2,3])
dizziness['moderate']=fuzz.trimf(dizziness.universe,[3,4.5,6])
dizziness['severe']=fuzz.trimf(dizziness.universe,[6,7,8])
dizziness['very severe']=fuzz.trimf(dizziness.universe,[8,9,10])
#------------------10.loss_of_appetie-------------
loss_of_appetie['mild']=fuzz.trimf(loss_of_appetie.universe,[1,2,3])
loss_of_appetie['moderate']=fuzz.trimf(loss_of_appetie.universe,[3,4.5,6])
loss_of_appetie['severe']=fuzz.trimf(loss_of_appetie.universe,[6,7,8])
loss_of_appetie['very severe']=fuzz.trimf(loss_of_appetie.universe,[8,9,10])
#------------------11.mp-------------
mp['mild']=fuzz.trimf(mp.universe,[1,2,3])
mp['moderate']=fuzz.trimf(mp.universe,[3,4.5,6])
mp['severe']=fuzz.trimf(mp.universe,[6,7,8])
mp['very severe']=fuzz.trimf(mp.universe,[8,9,10])
#------------------12.conclusion-------------
conclusion['mild']=fuzz.trimf(conclusion.universe,[1,2,3])
conclusion['moderate']=fuzz.trimf(conclusion.universe,[3,4.5,6])
conclusion['severe']=fuzz.trimf(conclusion.universe,[6,7,8])
conclusion['very severe']=fuzz.trimf(conclusion.universe,[8,9,10])


rule1 = ctrl.Rule(fever['mild']&headache['mild']&nausea['mild']&vomiting['mild']&jaundice['mild']&enlarge_liver['mild']&joint_pain['mild']&body_weakness['mild']&dizziness['severe']&loss_of_appetie['mild']&mp['mild'],conclusion['mild'])
rule2 = ctrl.Rule(fever['moderate']&headache['mild']&nausea['mild']&vomiting['mild']&jaundice['mild']&enlarge_liver['mild']&joint_pain['moderate']&body_weakness['moderate']&dizziness['severe']&loss_of_appetie['severe']&mp['moderate'],conclusion['moderate'])
rule3 = ctrl.Rule(fever['severe']&headache['moderate']&nausea['mild']&vomiting['mild']&jaundice['mild']&enlarge_liver['mild']&joint_pain['mild']&body_weakness['severe']&dizziness['severe']&loss_of_appetie['severe']&mp['moderate'],conclusion['severe'])
rule4 = ctrl.Rule(fever['very severe']&headache['mild']&nausea['mild']&vomiting['mild']&jaundice['mild']&enlarge_liver['mild']&joint_pain['severe']&body_weakness['severe']&dizziness['mild']&loss_of_appetie['mild']&mp['severe'],conclusion['very severe'])
rule5 = ctrl.Rule(fever['moderate']&headache['mild']&nausea['mild']&vomiting['moderate']&jaundice['mild']&enlarge_liver['mild']&joint_pain['moderate']&body_weakness['moderate']&dizziness['moderate']&loss_of_appetie['severe']&mp['moderate'],conclusion['moderate'])
rule6 = ctrl.Rule(fever['mild']&headache['moderate']&nausea['moderate']&vomiting['mild']&jaundice['mild']&enlarge_liver['mild']&joint_pain['mild']&body_weakness['mild']&dizziness['moderate']&loss_of_appetie['mild']&mp['mild'],conclusion['mild'])
rule7 = ctrl.Rule(fever['mild']&headache['mild']&nausea['moderate']&vomiting['moderate']&jaundice['mild']&enlarge_liver['mild']&joint_pain['severe']&body_weakness['severe']&dizziness['moderate']&loss_of_appetie['moderate']&mp['moderate'],conclusion['severe'])
rule8 = ctrl.Rule(fever['moderate']&headache['moderate']&nausea['moderate']&vomiting['moderate']&jaundice['moderate']&enlarge_liver['moderate']&joint_pain['moderate']&body_weakness['moderate']&dizziness['moderate']&loss_of_appetie['moderate']&mp['moderate'],conclusion['moderate'])
rule9 = ctrl.Rule(fever['moderate']&headache['mild']&nausea['moderate']&vomiting['moderate']&jaundice['mild']&enlarge_liver['severe']&joint_pain['moderate']&body_weakness['moderate']&dizziness['severe']&loss_of_appetie['moderate']&mp['moderate'],conclusion['moderate'])
rule10 = ctrl.Rule(fever['mild']&headache['mild']&nausea['moderate']&vomiting['moderate']&jaundice['mild']&enlarge_liver['moderate']&joint_pain['mild']&body_weakness['mild']&dizziness['mild']&loss_of_appetie['mild']&mp['mild'],conclusion['mild'])
rule11 = ctrl.Rule(fever['severe']&headache['severe']&nausea['severe']&vomiting['severe']&jaundice['severe']&enlarge_liver['severe']&joint_pain['severe']&body_weakness['very severe']&dizziness['severe']&loss_of_appetie['severe']&mp['moderate'],conclusion['very severe'])
rule12 = ctrl.Rule(fever['moderate']&headache['severe']&nausea['moderate']&vomiting['severe']&jaundice['moderate']&enlarge_liver['severe']&joint_pain['moderate']&body_weakness['severe']&dizziness['moderate']&loss_of_appetie['mild']&mp['moderate'],conclusion['severe'])
rule13 = ctrl.Rule(fever['mild']&headache['moderate']&nausea['moderate']&vomiting['moderate']&jaundice['mild']&enlarge_liver['mild']&joint_pain['mild']&body_weakness['moderate']&dizziness['mild']&loss_of_appetie['moderate']&mp['moderate'],conclusion['moderate'])
rule14 = ctrl.Rule(fever['severe']&headache['severe']&nausea['moderate']&vomiting['severe']&jaundice['severe']&enlarge_liver['severe']&joint_pain['severe']&body_weakness['severe']&dizziness['moderate']&loss_of_appetie['moderate']&mp['severe'],conclusion['severe'])
rule15 = ctrl.Rule(fever['mild']&headache['mild']&nausea['mild']&vomiting['moderate']&jaundice['mild']&enlarge_liver['mild']&joint_pain['mild']&body_weakness['severe']&dizziness['mild']&loss_of_appetie['severe']&mp['moderate'],conclusion['severe'])
rule16 = ctrl.Rule(fever['very severe']&headache['moderate']&nausea['mild']&vomiting['moderate']&jaundice['severe']&enlarge_liver['moderate']&joint_pain['mild']&body_weakness['very severe']&dizziness['severe']&loss_of_appetie['mild']&mp['moderate'],conclusion['very severe'])
rule17 = ctrl.Rule(fever['mild']&headache['very severe']&nausea['moderate']&vomiting['moderate']&jaundice['mild']&enlarge_liver['moderate']&joint_pain['mild']&body_weakness['moderate']&dizziness['very severe']&loss_of_appetie['mild']&mp['moderate'],conclusion['very severe'])
rule18 = ctrl.Rule(fever['moderate']&headache['very severe']&nausea['very severe']&vomiting['mild']&jaundice['severe']&enlarge_liver['severe']&joint_pain['moderate']&body_weakness['severe']&dizziness['very severe']&loss_of_appetie['very severe']&mp['severe'],conclusion['very severe'])
rule19 = ctrl.Rule(fever['moderate']&headache['moderate']&nausea['moderate']&vomiting['moderate']&jaundice['mild']&enlarge_liver['mild']&joint_pain['moderate']&body_weakness['moderate']&dizziness['moderate']&loss_of_appetie['moderate']&mp['moderate'],conclusion['moderate'])
rule20 = ctrl.Rule(fever['very severe']&headache['severe']&nausea['severe']&vomiting['severe']&jaundice['severe']&enlarge_liver['severe']&joint_pain['severe']&body_weakness['severe']&dizziness['severe']&loss_of_appetie['severe']&mp['moderate'],conclusion['very severe'])


conclusion_ctrl=ctrl.ControlSystem([rule1,rule2, rule3,rule4,rule5,rule6,rule7,rule8,rule9,rule10,rule11,rule12,rule13,rule13,rule14,rule15,rule16,rule17,rule18,rule19,rule20])
CtrlConclusion = ctrl.ControlSystemSimulation(conclusion_ctrl)
CtrlConclusion.input['fever']= 2.5
CtrlConclusion.input['headache']=2.5
CtrlConclusion.input['nausea']=2
CtrlConclusion.input['vomiting']=2
CtrlConclusion.input['jaundice']=2
CtrlConclusion.input['enlarge_liver']=2
CtrlConclusion.input['joint_pain']=2
CtrlConclusion.input['body_weakness']=2
CtrlConclusion.input['dizziness']=7
CtrlConclusion.input['loss_of_appetie']=2
CtrlConclusion.input['mp']=2
CtrlConclusion.compute()
print(CtrlConclusion.output['conclusion'])
conclusion.view(sim=CtrlConclusion)
# Out:
# 1.9999999999999998
