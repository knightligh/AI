# %% [markdown]
# <a href="https://colab.research.google.com/github/knightligh/AI/blob/main/demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
file ='/1.01. Simple linear regression (1).csv'
data = pd.read_csv(file)
data.head(21)
x1=np.array(data['SAT'])
y=np.array(data['GPA'])

#np.reshape(1, -1)
plt.scatter (x1,y)
plt.xlabel('SAT',fontsize =20 )
plt.ylabel('GPA',fontsize=20)
plt.show()
from sklearn import linear_model
regression_model = linear_model.LinearRegression()
regression_model.fit(x1,y)

print(regression_model.fit_intercept)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-b0cfb370b240> in <module>
#      15 from sklearn import linear_model
#      16 regression_model = linear_model.LinearRegression()
# ---> 17 regression_model.fit(x1,y)
#      18
#      19 print(regression_model.fit_intercept)
#
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_base.py in fit(self, X, y, sample_weight)
#     646         accept_sparse = False if self.positive else ["csr", "csc", "coo"]
#     647
# --> 648         X, y = self._validate_data(
#     649             X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     650         )
#
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     563                 y = check_array(y, input_name="y", **check_y_params)
#     564             else:
# --> 565                 X, y = check_X_y(X, y, **check_params)
#     566             out = X, y
#     567
#
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1104         )
#    1105
# -> 1106     X = check_array(
#    1107         X,
#    1108         accept_sparse=accept_sparse,
#
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     900             # If input is 1D raise error
#     901             if array.ndim == 1:
# --> 902                 raise ValueError(
#     903                     "Expected 2D array, got 1D array instead:\narray={}.\n"
#     904                     "Reshape your data either using array.reshape(-1, 1) if "
#
# ValueError: Expected 2D array, got 1D array instead:
# array=[1714 1664 1760 1685 1693 1670 1764 1764 1792 1850 1735 1775 1735 1712
#  1773 1872 1755 1674 1842 1786 1761 1722 1663 1687 1974 1826 1787 1821
#  2020 1794 1769 1934 1775 1855 1880 1849 1808 1954 1777 1831 1865 1850
#  1966 1702 1990 1925 1824 1956 1857 1979 1802 1855 1907 1634 1879 1887
#  1730 1953 1781 1891 1964 1808 1893 2041 1893 1832 1850 1934 1861 1931
#  1933 1778 1975 1934 2021 2015 1997 2020 1843 1936 1810 1987 1962 2050].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.

# %%
#bai tap 2 
#from pandas as pd 
url='/mtcars.csv'
data=pd.read_csv(url)
data.hist()
plt.show()
correlation = data.corr()
print(correlation)
X = data.drop(data.columns[[0,2]],axis=1)
data.plot(kind='scatter',x='wt',y='mpg',figsize=(9,9),color='black')
# Out:
#            mpg      disp        hp        wt
# mpg   1.000000 -0.847551 -0.776168 -0.867659
# disp -0.847551  1.000000  0.790949  0.887980
# hp   -0.776168  0.790949  1.000000  0.658748
# wt   -0.867659  0.887980  0.658748  1.000000
# <AxesSubplot:xlabel='wt', ylabel='mpg'>

# %%
#bai tap 3 hồi quy đa biến 
from sklearn import linear_model
model = linear_model.LinearRegression()
model.fit(X=pd.DataFrame(data['wt']),y=data['mpg'])
print(model.intercept_)
print(model.coef_)
model.score(pd.DataFrame(data['wt']),data['mpg'])# phan tram do tin cay
y_pred = model.predict(X=pd.DataFrame(data['wt']))
versidual = data['mpg']-y_pred
versidual.describe()

data.plot(kind='scatter',x='wt',y='mpg',figsize=(9,9),color='red')
plt.plot(data['wt'],y_pred,color='blue')
# Out:
# 37.28512616734204
# [-5.34447157]

# %%
#bai tap 4 
#DU LIEU HE BAC 2 
y=data['mpg']
model = linear_model.LinearRegression()
X = pd.DataFrame([data['wt'],data['wt']**2]).T
model.fit(X,y=data['mpg'])
print('Intercept cua no la hinh bac 2:')
print(model.intercept_)
print('coffient cua hinh bac 2 :')
print(model.coef_)
print('do chinh xac cua mo hinh :')
print(model.score(X,y))
# Out:
# Intercept cua no la hinh bac 2:
# 49.93081094945181
# coffient cua hinh bac 2 :
# [-13.38033708   1.17108689]
# do chinh xac cua mo hinh :
# 0.8190613581384094

# %%
#bai tap so 5 
#dữ liệu bậc 2
range = np.arange (1.5,5.5,0.1)
predictor = pd.DataFrame([range,range**2]).T
y_pred = model.predict (X=predictor)
data.plot(kind='scatter',x='wt',y='mpg',figsize=(9,9),color='red',xlim=(0,7))
plt.plot(range,y_pred,color='blue')
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
#bài tập 5 
#dữ liệu dạng bậc 3
y=data['mpg']
model = linear_model.LinearRegression()
X = pd.DataFrame([data['wt'],data['wt']**2,data['wt']**3]).T
model.fit(X,y=data['mpg'])
range = np.arange (1.5,5.5,0.1)
predictor = pd.DataFrame([range,range**2,range**3]).T
y_pred = model.predict (X=predictor)
data.plot(kind='scatter',x='wt',y='mpg',figsize=(9,9),color='red',xlim=(0,7))
plt.plot(range,y_pred,color='blue')
print('do chinh xac cua mo hinh :')
print(model.score(X,y))
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# do chinh xac cua mo hinh :
# 0.8191284628478992

# %%
#bài tập 6
#dữ liệu dạng bậc 10
y=data['mpg']
model = linear_model.LinearRegression()
X = pd.DataFrame([data['wt'],data['wt']**2,data['wt']**3,data['wt']**4,data['wt']**5,data['wt']**6,data['wt']**7,data['wt']**8,data['wt']**9,data['wt']**10]).T
model.fit(X,y=data['mpg'])
range = np.arange (1.5,5.5,0.1)
predictor = pd.DataFrame([range,range**2,range**3,range**4,range**5,range**6,range**7,range**8,range**9,range**10]).T
y_pred = model.predict (X=predictor)
data.plot(kind='scatter',x='wt',y='mpg',figsize=(9,9),color='red',xlim=(0,7))
plt.plot(range,y_pred,color='blue')
print('do chinh xac cua mo hinh :')
print(model.score(X,y))
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# do chinh xac cua mo hinh :
# 0.8702106571479111

# %%
#II/phân tích dữu liệu của start-up
import numpy as np
import matplotlib.pyplot as plt

import pandas as pd 
import seaborn as sns

data=pd.read_csv ('/50_Startups.csv')
data.head 
#hiển tị theo cặhp dữ liệu 
sns.pairplot(data)

corr=data.corr()
sns.heatmap(corr,annot=True)

X =data.drop('Profit',axis=True)#xoá cột dữ liệu profit
X =data.drop('State',axis=True)#xoá cột dữ  liệu state 
y=data['Profit']
X.head()

from sklearn.preprocessing import StandardScaler#tỉ lệ hoá số liệu (normal line số liệu)
SC=StandardScaler()
X=SC.fit_transform(X)

from sklearn.model_selection import train_test_split
X_train ,X_test,y_train ,y_test=train_test_split(X,y,test_size=0.2,random_state=0)
X_train.shape
X_test.shape
y_train.shape
y_test.shape
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train,y_train)
y_pred = regressor.predict(X_test).round(1)
caculation = pd.DataFrame(np.c_[y_test,y_pred],columns=['Original Profit','Predicted Profit'])
print('do chinh xac cua mo hinh :')
print(regressor.score(X_train,y_train))
# Out:
# do chinh xac cua mo hinh :
# 1.0

# %%
#III/ ADVERTISING 
import numpy as np
import matplotlib.pyplot as plt

import pandas as pd 
import seaborn as sns

data=pd.read_csv ('Advertising.csv')
data.head 
#hiển tị theo cặhp dữ liệu 
sns.pairplot(data)

# %%
corr = data.corr()
sns.heatmap(corr,annot=True)
# Out:
# <AxesSubplot:>

# %%
y=data['TV']
model = linear_model.LinearRegression()
X = pd.DataFrame([data['sales'],data['sales']**2,data['sales']**3,data['sales']**4]).T
model.fit(X,y=data['TV'])
range = np.arange (1.5,5.5,0.1)
predictor = pd.DataFrame([range,range**2,range**3,range**4,range**5,range**6,range**7,range**8,range**9,range**10]).T

data.plot(kind='scatter',x='sales',y='TV',figsize=(9,9),color='red',xlim=(0,7))
plt.plot(range,y_pred,color='blue')
print('do chinh xac cua mo hinh :')
print(model.score(X,y))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-86-646ea7ced81b> in <module>
#       7
#       8 data.plot(kind='scatter',x='sales',y='TV',figsize=(9,9),color='red',xlim=(0,7))
# ----> 9 plt.plot(range,y_pred,color='blue')
#      10 print('do chinh xac cua mo hinh :')
#      11 print(model.score(X,y))
#
# /usr/local/lib/python3.9/dist-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2765 @_copy_docstring_and_deprecators(Axes.plot)
#    2766 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2767     return gca().plot(
#    2768         *args, scalex=scalex, scaley=scaley,
#    2769         **({"data": data} if data is not None else {}), **kwargs)
#
# /usr/local/lib/python3.9/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1633         """
#    1634         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1635         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1636         for line in lines:
#    1637             self.add_line(line)
#
# /usr/local/lib/python3.9/dist-packages/matplotlib/axes/_base.py in __call__(self, data, *args, **kwargs)
#     310                 this += args[0],
#     311                 args = args[1:]
# --> 312             yield from self._plot_args(this, kwargs)
#     313
#     314     def get_next_color(self):
#
# /usr/local/lib/python3.9/dist-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs, return_kwargs)
#     496
#     497         if x.shape[0] != y.shape[0]:
# --> 498             raise ValueError(f"x and y must have same first dimension, but "
#     499                              f"have shapes {x.shape} and {y.shape}")
#     500         if x.ndim > 2 or y.ndim > 2:
#
# ValueError: x and y must have same first dimension, but have shapes (40,) and (10,)
